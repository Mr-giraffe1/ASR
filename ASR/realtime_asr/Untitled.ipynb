# %%
# -*- coding: utf-8 -*-
"""
实时流式识别
需要安装websocket-client库
使用方式 python realtime_asr.py 16k-0.pcm
"""
import websocket
import threading
import time
import uuid
import json
import logging
import sys
import const

# if len(sys.argv) < 2:
#     pcm_file = "16k-0.pcm"
# else:
pcm_file = 'long.pcm'

logger = logging.getLogger()

"""

1. 连接 ws_app.run_forever()
2. 连接成功后发送数据 on_open()
2.1 发送开始参数帧 send_start_params()
2.2 发送音频数据帧 send_audio()
2.3 库接收识别结果 on_message()
2.4 发送结束帧 send_finish()
3. 关闭连接 on_close()

库的报错 on_error()
"""


def send_start_params(ws):
    """
    开始参数帧
    :param websocket.WebSocket ws:
    :return:
    """
    req = {
        "type": "START",
        "data": {
            "appid": 22834963,  # 网页上的appid
            "appkey": 'GY7dRpHrj9rYpwrcfTuSg2zp',  # 网页上的appid对应的appkey
            "dev_pid": 15372,  # 识别模型
            "cuid": "yourself_defined_user_id001",  # 随便填不影响使用。机器的mac或者其它唯一id，百度计算UV用。
            "sample": 16000,  # 固定参数
            "format": "pcm"  # 固定参数
        }
    }
    body = json.dumps(req)
    ws.send(body, websocket.ABNF.OPCODE_TEXT)
    logger.info("send START frame with params:" + body)


def send_audio(ws):
    """
    发送二进制音频数据，注意每个帧之间需要有间隔时间
    :param  websocket.WebSocket ws:
    :return:
    """
    chunk_ms = 160  # 160ms的录音
    chunk_len = int(16000 * 2 / 1000 * chunk_ms)
    with open(pcm_file, 'rb') as f:
        pcm = f.read()

    index = 0
    total = len(pcm)
    logger.info("send_audio total={}".format(total))
    while index < total:
        end = index + chunk_len
        if end >= total:
            # 最后一个音频数据帧
            end = total
        body = pcm[index:end]
        logger.debug("try to send audio length {}, from bytes [{},{})".format(len(body), index, end))
        ws.send(body, websocket.ABNF.OPCODE_BINARY)
        index = end
        time.sleep(chunk_ms / 1000.0)  # ws.send 也有点耗时，这里没有计算


def send_finish(ws):
    """
    发送结束帧
    :param websocket.WebSocket ws:
    :return:
    """
    req = {
        "type": "FINISH"
    }
    body = json.dumps(req)
    ws.send(body, websocket.ABNF.OPCODE_TEXT)
    logger.info("send FINISH frame")


def send_cancel(ws):
    """
    发送取消帧
    :param websocket.WebSocket ws:
    :return:
    """
    req = {
        "type": "CANCEL"
    }
    body = json.dumps(req)
    ws.send(body, websocket.ABNF.OPCODE_TEXT)
    logger.info("send Cancel frame")


def on_open(ws):
    """
    连接后发送数据帧
    :param  websocket.WebSocket ws:
    :return:
    """

    def run(*args):
        """
        发送数据帧
        :param args:
        :return:
        """
        send_start_params(ws)
        send_audio(ws)
        send_finish(ws)
        logger.debug("thread terminating")

    threading.Thread(target=run).start()


def on_message(ws, message):
    """
    接收服务端返回的消息
    :param ws:
    :param message: json格式，自行解析
    :return:
    """
    logger.info("Response: " + message)


def on_error(ws, error):
    """
    库的报错，比如连接超时
    :param ws:
    :param error: json格式，自行解析
    :return:
        """
    logger.error("error: " + str(error))


def on_close(ws):
    """
    Websocket关闭
    :param websocket.WebSocket ws:
    :return:
    """
    logger.info("ws close ...")
    # ws.close()

# %%
logging.basicConfig(format='[%(asctime)-15s] [%(funcName)s()][%(levelname)s] %(message)s')
logger.setLevel(logging.DEBUG)  # 调整为logging.INFO，日志会少一点
logger.info("begin")
# websocket.enableTrace(True)
uri = const.URI + "?sn=" + str(uuid.uuid1())
logger.info("uri is "+ uri)
ws_app = websocket.WebSocketApp(uri,
                                on_open=on_open,  # 连接建立后的回调
                                on_message=on_message,  # 接收消息的回调
                                on_error=on_error,  # 库遇见错误的回调
                                on_close=on_close)  # 关闭后的回调
ws_app.run_forever()
# Out:
# [2020-12-07 10:27:16,564] [<module>()][INFO] begin
# [2020-12-07 10:27:16,565] [<module>()][INFO] uri is ws://vop.baidu.com/realtime_asr?sn=b9255c4c-3833-11eb-982f-505bc2c1a470
# [2020-12-07 10:27:16,603] [send_start_params()][INFO] send START frame with params:{"type": "START", "data": {"appid": 22834963, "appkey": "GY7dRpHrj9rYpwrcfTuSg2zp", "dev_pid": 15372, "cuid": "yourself_defined_user_id001", "sample": 16000, "format": "pcm"}}
# [2020-12-07 10:27:16,609] [send_audio()][INFO] send_audio total=4621824
# [2020-12-07 10:27:16,610] [send_audio()][DEBUG] try to send audio length 5120, from bytes [0,5120)
# [2020-12-07 10:27:16,772] [send_audio()][DEBUG] try to send audio length 5120, from bytes [5120,10240)
# [2020-12-07 10:27:16,934] [send_audio()][DEBUG] try to send audio length 5120, from bytes [10240,15360)
# [2020-12-07 10:27:16,954] [on_message()][INFO] Response: {"type":"HEARTBEAT"}
#
# [2020-12-07 10:27:17,096] [send_audio()][DEBUG] try to send audio length 5120, from bytes [15360,20480)
# [2020-12-07 10:27:17,258] [send_audio()][DEBUG] try to send audio length 5120, from bytes [20480,25600)
# [2020-12-07 10:27:17,420] [send_audio()][DEBUG] try to send audio length 5120, from bytes [25600,30720)
# [2020-12-07 10:27:17,582] [send_audio()][DEBUG] try to send audio length 5120, from bytes [30720,35840)
# [2020-12-07 10:27:17,744] [send_audio()][DEBUG] try to send audio length 5120, from bytes [35840,40960)
# [2020-12-07 10:27:17,907] [send_audio()][DEBUG] try to send audio length 5120, from bytes [40960,46080)
# [2020-12-07 10:27:18,069] [send_audio()][DEBUG] try to send audio length 5120, from bytes [46080,51200)
# [2020-12-07 10:27:18,231] [send_audio()][DEBUG] try to send audio length 5120, from bytes [51200,56320)
# [2020-12-07 10:27:18,393] [send_audio()][DEBUG] try to send audio length 5120, from bytes [56320,61440)
# [2020-12-07 10:27:18,555] [send_audio()][DEBUG] try to send audio length 5120, from bytes [61440,66560)
# [2020-12-07 10:27:18,717] [send_audio()][DEBUG] try to send audio length 5120, from bytes [66560,71680)
# [2020-12-07 10:27:18,879] [send_audio()][DEBUG] try to send audio length 5120, from bytes [71680,76800)
# [2020-12-07 10:27:19,040] [send_audio()][DEBUG] try to send audio length 5120, from bytes [76800,81920)
# [2020-12-07 10:27:19,202] [send_audio()][DEBUG] try to send audio length 5120, from bytes [81920,87040)
# [2020-12-07 10:27:19,364] [send_audio()][DEBUG] try to send audio length 5120, from bytes [87040,92160)
# [2020-12-07 10:27:19,499] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:19,527] [send_audio()][DEBUG] try to send audio length 5120, from bytes [92160,97280)
# [2020-12-07 10:27:19,688] [send_audio()][DEBUG] try to send audio length 5120, from bytes [97280,102400)
# [2020-12-07 10:27:19,790] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:19,850] [send_audio()][DEBUG] try to send audio length 5120, from bytes [102400,107520)
# [2020-12-07 10:27:19,984] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:20,012] [send_audio()][DEBUG] try to send audio length 5120, from bytes [107520,112640)
# [2020-12-07 10:27:20,174] [send_audio()][DEBUG] try to send audio length 5120, from bytes [112640,117760)
# [2020-12-07 10:27:20,335] [send_audio()][DEBUG] try to send audio length 5120, from bytes [117760,122880)
# [2020-12-07 10:27:20,498] [send_audio()][DEBUG] try to send audio length 5120, from bytes [122880,128000)
# [2020-12-07 10:27:20,660] [send_audio()][DEBUG] try to send audio length 5120, from bytes [128000,133120)
# [2020-12-07 10:27:20,822] [send_audio()][DEBUG] try to send audio length 5120, from bytes [133120,138240)
# [2020-12-07 10:27:20,984] [send_audio()][DEBUG] try to send audio length 5120, from bytes [138240,143360)
# [2020-12-07 10:27:21,146] [send_audio()][DEBUG] try to send audio length 5120, from bytes [143360,148480)
# [2020-12-07 10:27:21,307] [send_audio()][DEBUG] try to send audio length 5120, from bytes [148480,153600)
# [2020-12-07 10:27:21,469] [send_audio()][DEBUG] try to send audio length 5120, from bytes [153600,158720)
# [2020-12-07 10:27:21,631] [send_audio()][DEBUG] try to send audio length 5120, from bytes [158720,163840)
# [2020-12-07 10:27:21,651] [on_message()][INFO] Response: {"type":"HEARTBEAT"}
#
# [2020-12-07 10:27:21,793] [send_audio()][DEBUG] try to send audio length 5120, from bytes [163840,168960)
# [2020-12-07 10:27:21,955] [send_audio()][DEBUG] try to send audio length 5120, from bytes [168960,174080)
# [2020-12-07 10:27:22,117] [send_audio()][DEBUG] try to send audio length 5120, from bytes [174080,179200)
# [2020-12-07 10:27:22,279] [send_audio()][DEBUG] try to send audio length 5120, from bytes [179200,184320)
# [2020-12-07 10:27:22,418] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:22,440] [send_audio()][DEBUG] try to send audio length 5120, from bytes [184320,189440)
# [2020-12-07 10:27:22,602] [send_audio()][DEBUG] try to send audio length 5120, from bytes [189440,194560)
# [2020-12-07 10:27:22,764] [send_audio()][DEBUG] try to send audio length 5120, from bytes [194560,199680)
# [2020-12-07 10:27:22,926] [send_audio()][DEBUG] try to send audio length 5120, from bytes [199680,204800)
# [2020-12-07 10:27:23,088] [send_audio()][DEBUG] try to send audio length 5120, from bytes [204800,209920)
# [2020-12-07 10:27:23,251] [send_audio()][DEBUG] try to send audio length 5120, from bytes [209920,215040)
# [2020-12-07 10:27:23,413] [send_audio()][DEBUG] try to send audio length 5120, from bytes [215040,220160)
# [2020-12-07 10:27:23,575] [send_audio()][DEBUG] try to send audio length 5120, from bytes [220160,225280)
# [2020-12-07 10:27:23,736] [send_audio()][DEBUG] try to send audio length 5120, from bytes [225280,230400)
# [2020-12-07 10:27:23,898] [send_audio()][DEBUG] try to send audio length 5120, from bytes [230400,235520)
# [2020-12-07 10:27:24,027] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的您身边","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:24,060] [send_audio()][DEBUG] try to send audio length 5120, from bytes [235520,240640)
# [2020-12-07 10:27:24,194] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的您身边或","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:24,222] [send_audio()][DEBUG] try to send audio length 5120, from bytes [240640,245760)
# [2020-12-07 10:27:24,354] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:24,384] [send_audio()][DEBUG] try to send audio length 5120, from bytes [245760,250880)
# [2020-12-07 10:27:24,546] [send_audio()][DEBUG] try to send audio length 5120, from bytes [250880,256000)
# [2020-12-07 10:27:24,649] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:24,707] [send_audio()][DEBUG] try to send audio length 5120, from bytes [256000,261120)
# [2020-12-07 10:27:24,850] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:24,869] [send_audio()][DEBUG] try to send audio length 5120, from bytes [261120,266240)
# [2020-12-07 10:27:25,032] [send_audio()][DEBUG] try to send audio length 5120, from bytes [266240,271360)
# [2020-12-07 10:27:25,127] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:25,194] [send_audio()][DEBUG] try to send audio length 5120, from bytes [271360,276480)
# [2020-12-07 10:27:25,356] [send_audio()][DEBUG] try to send audio length 5120, from bytes [276480,281600)
# [2020-12-07 10:27:25,518] [send_audio()][DEBUG] try to send audio length 5120, from bytes [281600,286720)
# [2020-12-07 10:27:25,680] [send_audio()][DEBUG] try to send audio length 5120, from bytes [286720,291840)
# [2020-12-07 10:27:25,842] [send_audio()][DEBUG] try to send audio length 5120, from bytes [291840,296960)
# [2020-12-07 10:27:25,974] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:26,006] [send_audio()][DEBUG] try to send audio length 5120, from bytes [296960,302080)
# [2020-12-07 10:27:26,110] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人让我","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:26,168] [send_audio()][DEBUG] try to send audio length 5120, from bytes [302080,307200)
# [2020-12-07 10:27:26,294] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:26,330] [send_audio()][DEBUG] try to send audio length 5120, from bytes [307200,312320)
# [2020-12-07 10:27:26,492] [send_audio()][DEBUG] try to send audio length 5120, from bytes [312320,317440)
# [2020-12-07 10:27:26,494] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们家","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:26,654] [send_audio()][DEBUG] try to send audio length 5120, from bytes [317440,322560)
# [2020-12-07 10:27:26,673] [on_message()][INFO] Response: {"type":"HEARTBEAT"}
#
# [2020-12-07 10:27:26,816] [send_audio()][DEBUG] try to send audio length 5120, from bytes [322560,327680)
# [2020-12-07 10:27:26,977] [send_audio()][DEBUG] try to send audio length 5120, from bytes [327680,332800)
# [2020-12-07 10:27:27,112] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们家坐着","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:27,139] [send_audio()][DEBUG] try to send audio length 5120, from bytes [332800,337920)
# [2020-12-07 10:27:27,301] [send_audio()][DEBUG] try to send audio length 5120, from bytes [337920,343040)
# [2020-12-07 10:27:27,402] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们家坐着一","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:27,463] [send_audio()][DEBUG] try to send audio length 5120, from bytes [343040,348160)
# [2020-12-07 10:27:27,557] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们家人民医院","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:27,625] [send_audio()][DEBUG] try to send audio length 5120, from bytes [348160,353280)
# [2020-12-07 10:27:27,787] [send_audio()][DEBUG] try to send audio length 5120, from bytes [353280,358400)
# [2020-12-07 10:27:27,948] [send_audio()][DEBUG] try to send audio length 5120, from bytes [358400,363520)
# [2020-12-07 10:27:28,047] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们家人民医院住院","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:28,110] [send_audio()][DEBUG] try to send audio length 5120, from bytes [363520,368640)
# [2020-12-07 10:27:28,232] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们家人民医院住院治","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:28,272] [send_audio()][DEBUG] try to send audio length 5120, from bytes [368640,373760)
# [2020-12-07 10:27:28,434] [send_audio()][DEBUG] try to send audio length 5120, from bytes [373760,378880)
# [2020-12-07 10:27:28,595] [send_audio()][DEBUG] try to send audio length 5120, from bytes [378880,384000)
# [2020-12-07 10:27:28,757] [send_audio()][DEBUG] try to send audio length 5120, from bytes [384000,389120)
# [2020-12-07 10:27:28,765] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们家人民医院住院治疗","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:28,919] [send_audio()][DEBUG] try to send audio length 5120, from bytes [389120,394240)
# [2020-12-07 10:27:29,081] [send_audio()][DEBUG] try to send audio length 5120, from bytes [394240,399360)
# [2020-12-07 10:27:29,209] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们家人民医院住院治疗现在我","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:29,243] [send_audio()][DEBUG] try to send audio length 5120, from bytes [399360,404480)
# [2020-12-07 10:27:29,335] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们家人民医院住院治疗现在我们","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:29,405] [send_audio()][DEBUG] try to send audio length 5120, from bytes [404480,409600)
# [2020-12-07 10:27:29,506] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们家人民医院住院治疗现在我们做","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:29,567] [send_audio()][DEBUG] try to send audio length 5120, from bytes [409600,414720)
# [2020-12-07 10:27:29,708] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们家人民医院住院治疗现在我们做一","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:29,729] [send_audio()][DEBUG] try to send audio length 5120, from bytes [414720,419840)
# [2020-12-07 10:27:29,891] [send_audio()][DEBUG] try to send audio length 5120, from bytes [419840,424960)
# [2020-12-07 10:27:29,990] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们家人民医院住院治疗现在我们做一下","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:30,053] [send_audio()][DEBUG] try to send audio length 5120, from bytes [424960,430080)
# [2020-12-07 10:27:30,215] [send_audio()][DEBUG] try to send audio length 5120, from bytes [430080,435200)
# [2020-12-07 10:27:30,377] [send_audio()][DEBUG] try to send audio length 5120, from bytes [435200,440320)
# [2020-12-07 10:27:30,540] [send_audio()][DEBUG] try to send audio length 5120, from bytes [440320,445440)
# [2020-12-07 10:27:30,701] [send_audio()][DEBUG] try to send audio length 5120, from bytes [445440,450560)
# [2020-12-07 10:27:30,818] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们家人民医院住院治疗现在我们做一下哪个","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:30,863] [send_audio()][DEBUG] try to send audio length 5120, from bytes [450560,455680)
# [2020-12-07 10:27:31,026] [send_audio()][DEBUG] try to send audio length 5120, from bytes [455680,460800)
# [2020-12-07 10:27:31,188] [send_audio()][DEBUG] try to send audio length 5120, from bytes [460800,465920)
# [2020-12-07 10:27:31,342] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们家人民医院住院治疗现在我们做一下哪个知道","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:31,350] [send_audio()][DEBUG] try to send audio length 5120, from bytes [465920,471040)
# [2020-12-07 10:27:31,511] [send_audio()][DEBUG] try to send audio length 5120, from bytes [471040,476160)
# [2020-12-07 10:27:31,646] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们家人民医院住院治疗现在我们做一下这个调查","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:31,673] [send_audio()][DEBUG] try to send audio length 5120, from bytes [476160,481280)
# [2020-12-07 10:27:31,692] [on_message()][INFO] Response: {"type":"HEARTBEAT"}
#
# [2020-12-07 10:27:31,835] [send_audio()][DEBUG] try to send audio length 5120, from bytes [481280,486400)
# [2020-12-07 10:27:31,997] [send_audio()][DEBUG] try to send audio length 5120, from bytes [486400,491520)
# [2020-12-07 10:27:32,139] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们家人民医院住院治疗现在我们做一下这个调查你看","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:32,158] [send_audio()][DEBUG] try to send audio length 5120, from bytes [491520,496640)
# [2020-12-07 10:27:32,269] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们家人民医院住院治疗现在我们做一下这个调查你看方","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:32,320] [send_audio()][DEBUG] try to send audio length 5120, from bytes [496640,501760)
# [2020-12-07 10:27:32,482] [send_audio()][DEBUG] try to send audio length 5120, from bytes [501760,506880)
# [2020-12-07 10:27:32,615] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们家人民医院住院治疗现在我们做一下这个调查您看方便","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:32,644] [send_audio()][DEBUG] try to send audio length 5120, from bytes [506880,512000)
# [2020-12-07 10:27:32,805] [send_audio()][DEBUG] try to send audio length 5120, from bytes [512000,517120)
# [2020-12-07 10:27:32,968] [send_audio()][DEBUG] try to send audio length 5120, from bytes [517120,522240)
# [2020-12-07 10:27:33,129] [send_audio()][DEBUG] try to send audio length 5120, from bytes [522240,527360)
# [2020-12-07 10:27:33,291] [send_audio()][DEBUG] try to send audio length 5120, from bytes [527360,532480)
# [2020-12-07 10:27:33,453] [send_audio()][DEBUG] try to send audio length 5120, from bytes [532480,537600)
# [2020-12-07 10:27:33,582] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们家人民医院住院治疗现在我们做一下这个调查您看方便吗","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:33,615] [send_audio()][DEBUG] try to send audio length 5120, from bytes [537600,542720)
# [2020-12-07 10:27:33,777] [send_audio()][DEBUG] try to send audio length 5120, from bytes [542720,547840)
# [2020-12-07 10:27:33,939] [send_audio()][DEBUG] try to send audio length 5120, from bytes [547840,552960)
# [2020-12-07 10:27:34,100] [send_audio()][DEBUG] try to send audio length 5120, from bytes [552960,558080)
# [2020-12-07 10:27:34,262] [send_audio()][DEBUG] try to send audio length 5120, from bytes [558080,563200)
# [2020-12-07 10:27:34,424] [send_audio()][DEBUG] try to send audio length 5120, from bytes [563200,568320)
# [2020-12-07 10:27:34,587] [send_audio()][DEBUG] try to send audio length 5120, from bytes [568320,573440)
# [2020-12-07 10:27:34,749] [send_audio()][DEBUG] try to send audio length 5120, from bytes [573440,578560)
# [2020-12-07 10:27:34,911] [send_audio()][DEBUG] try to send audio length 5120, from bytes [578560,583680)
# [2020-12-07 10:27:35,073] [send_audio()][DEBUG] try to send audio length 5120, from bytes [583680,588800)
# [2020-12-07 10:27:35,235] [send_audio()][DEBUG] try to send audio length 5120, from bytes [588800,593920)
# [2020-12-07 10:27:35,398] [send_audio()][DEBUG] try to send audio length 5120, from bytes [593920,599040)
# [2020-12-07 10:27:35,560] [send_audio()][DEBUG] try to send audio length 5120, from bytes [599040,604160)
# [2020-12-07 10:27:35,721] [send_audio()][DEBUG] try to send audio length 5120, from bytes [604160,609280)
# [2020-12-07 10:27:35,883] [send_audio()][DEBUG] try to send audio length 5120, from bytes [609280,614400)
# [2020-12-07 10:27:36,045] [send_audio()][DEBUG] try to send audio length 5120, from bytes [614400,619520)
# [2020-12-07 10:27:36,207] [send_audio()][DEBUG] try to send audio length 5120, from bytes [619520,624640)
# [2020-12-07 10:27:36,369] [send_audio()][DEBUG] try to send audio length 5120, from bytes [624640,629760)
# [2020-12-07 10:27:36,531] [send_audio()][DEBUG] try to send audio length 5120, from bytes [629760,634880)
# [2020-12-07 10:27:36,625] [on_message()][INFO] Response: {"type":"HEARTBEAT"}
#
# [2020-12-07 10:27:36,694] [send_audio()][DEBUG] try to send audio length 5120, from bytes [634880,640000)
# [2020-12-07 10:27:36,714] [on_message()][INFO] Response: {"type":"HEARTBEAT"}
#
# [2020-12-07 10:27:36,856] [send_audio()][DEBUG] try to send audio length 5120, from bytes [640000,645120)
# [2020-12-07 10:27:37,018] [send_audio()][DEBUG] try to send audio length 5120, from bytes [645120,650240)
# [2020-12-07 10:27:37,180] [send_audio()][DEBUG] try to send audio length 5120, from bytes [650240,655360)
# [2020-12-07 10:27:37,343] [send_audio()][DEBUG] try to send audio length 5120, from bytes [655360,660480)
# [2020-12-07 10:27:37,505] [send_audio()][DEBUG] try to send audio length 5120, from bytes [660480,665600)
# [2020-12-07 10:27:37,667] [send_audio()][DEBUG] try to send audio length 5120, from bytes [665600,670720)
# [2020-12-07 10:27:37,829] [send_audio()][DEBUG] try to send audio length 5120, from bytes [670720,675840)
# [2020-12-07 10:27:37,991] [send_audio()][DEBUG] try to send audio length 5120, from bytes [675840,680960)
# [2020-12-07 10:27:38,152] [send_audio()][DEBUG] try to send audio length 5120, from bytes [680960,686080)
# [2020-12-07 10:27:38,314] [send_audio()][DEBUG] try to send audio length 5120, from bytes [686080,691200)
# [2020-12-07 10:27:38,477] [send_audio()][DEBUG] try to send audio length 5120, from bytes [691200,696320)
# [2020-12-07 10:27:38,638] [send_audio()][DEBUG] try to send audio length 5120, from bytes [696320,701440)
# [2020-12-07 10:27:38,800] [send_audio()][DEBUG] try to send audio length 5120, from bytes [701440,706560)
# [2020-12-07 10:27:38,962] [send_audio()][DEBUG] try to send audio length 5120, from bytes [706560,711680)
# [2020-12-07 10:27:39,123] [send_audio()][DEBUG] try to send audio length 5120, from bytes [711680,716800)
# [2020-12-07 10:27:39,285] [send_audio()][DEBUG] try to send audio length 5120, from bytes [716800,721920)
# [2020-12-07 10:27:39,447] [send_audio()][DEBUG] try to send audio length 5120, from bytes [721920,727040)
# [2020-12-07 10:27:39,609] [send_audio()][DEBUG] try to send audio length 5120, from bytes [727040,732160)
# [2020-12-07 10:27:39,744] [on_message()][INFO] Response: {"type":"HEARTBEAT"}
#
# [2020-12-07 10:27:39,771] [send_audio()][DEBUG] try to send audio length 5120, from bytes [732160,737280)
# [2020-12-07 10:27:39,933] [send_audio()][DEBUG] try to send audio length 5120, from bytes [737280,742400)
# [2020-12-07 10:27:39,934] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们家人民医院住院治疗现在我们做一下这个调查您看方便吗您一生","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:40,094] [send_audio()][DEBUG] try to send audio length 5120, from bytes [742400,747520)
# [2020-12-07 10:27:40,199] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们家人民医院住院治疗现在我们做一下这个调查您看方便吗您一生的","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:40,256] [send_audio()][DEBUG] try to send audio length 5120, from bytes [747520,752640)
# [2020-12-07 10:27:40,389] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们家人民医院住院治疗现在我们做一下这个调查您看方便吗您一生的服务","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:40,418] [send_audio()][DEBUG] try to send audio length 5120, from bytes [752640,757760)
# [2020-12-07 10:27:40,580] [send_audio()][DEBUG] try to send audio length 5120, from bytes [757760,762880)
# [2020-12-07 10:27:40,741] [send_audio()][DEBUG] try to send audio length 5120, from bytes [762880,768000)
# [2020-12-07 10:27:40,904] [send_audio()][DEBUG] try to send audio length 5120, from bytes [768000,773120)
# [2020-12-07 10:27:41,066] [send_audio()][DEBUG] try to send audio length 5120, from bytes [773120,778240)
# [2020-12-07 10:27:41,228] [send_audio()][DEBUG] try to send audio length 5120, from bytes [778240,783360)
# [2020-12-07 10:27:41,367] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们家人民医院住院治疗现在我们做一下这个调查您看方便吗您一生的服务满不满","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:41,390] [send_audio()][DEBUG] try to send audio length 5120, from bytes [783360,788480)
# [2020-12-07 10:27:41,553] [send_audio()][DEBUG] try to send audio length 5120, from bytes [788480,793600)
# [2020-12-07 10:27:41,648] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们家人民医院住院治疗现在我们做一下这个调查您看方便吗您一生的服务满不满意","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:41,715] [send_audio()][DEBUG] try to send audio length 5120, from bytes [793600,798720)
# [2020-12-07 10:27:41,736] [on_message()][INFO] Response: {"type":"HEARTBEAT"}
#
# [2020-12-07 10:27:41,877] [send_audio()][DEBUG] try to send audio length 5120, from bytes [798720,803840)
# [2020-12-07 10:27:42,038] [send_audio()][DEBUG] try to send audio length 5120, from bytes [803840,808960)
# [2020-12-07 10:27:42,201] [send_audio()][DEBUG] try to send audio length 5120, from bytes [808960,814080)
# [2020-12-07 10:27:42,363] [send_audio()][DEBUG] try to send audio length 5120, from bytes [814080,819200)
# [2020-12-07 10:27:42,525] [send_audio()][DEBUG] try to send audio length 5120, from bytes [819200,824320)
# [2020-12-07 10:27:42,627] [on_message()][INFO] Response: {"err_msg":"OK","err_no":0,"log_id":1376621140,"result":"你好我是办公室的会议您这边或者交易有人在我们家人民医院住院治疗现在我们做一下这个调查您看方便吗您一生的服务满不满意啊","sn":"b9255c4c-3833-11eb-982f-505bc2c1a470_ws_0","type":"MID_TEXT"}
#
# [2020-12-07 10:27:42,687] [send_audio()][DEBUG] try to send audio length 5120, from bytes [824320,829440)
# [2020-12-07 10:27:42,850] [send_audio()][DEBUG] try to send audio length 5120, from bytes [829440,834560)
# [2020-12-07 10:27:43,013] [send_audio()][DEBUG] try to send audio length 5120, from bytes [834560,839680)
# [2020-12-07 10:27:43,175] [send_audio()][DEBUG] try to send audio length 5120, from bytes [839680,844800)
# [2020-12-07 10:27:43,337] [send_audio()][DEBUG] try to send audio length 5120, from bytes [844800,849920)
